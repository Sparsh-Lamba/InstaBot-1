# %%
conda install selenium
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select             #To use implcit and explicit wait
from selenium.webdriver.support import expected_conditions as EC           #use in explicitly wait
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup                                              #work with attribute 
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException

# %% [markdown]
# ## LOGIN USING INSTA USERNAME AND PASSWORD

# %%
driver = webdriver.Chrome(executable_path = r'\Users\spars\Downloads\chromedriver')             #invoke chrome webdriver
driver.get('https://www.instagram.com/')
time.sleep(2)
username = driver.find_element_by_name('username')
password = driver.find_element_by_name('password')

username.click()
username.send_keys('*********')
time.sleep(1)                                                 ##pass your own username and password

password.click()
password.send_keys('*********')
time.sleep(1)

log_in=driver.find_element_by_xpath('//div[text()="Log In"]')
log_in.click()
time.sleep(4)

# credential storage
try:
    credentials= driver.find_element_by_xpath('//button[text()="Not Now"]')
    credentials.click()
    time.sleep(1)
except:
    pass

#  notifications
try:
    notifications = driver.find_element_by_xpath('//button[text()="Not Now"]')
    notifications.click()
    time.sleep(1)
except:
    pass

# %% [markdown]
# ## Searching Food and printing names of Instagram Handles

# %%
search=driver.find_element_by_xpath('//span[text()="Search"]')
search.click()
time.sleep(1)
searchfood= driver.find_element_by_xpath('//input[@placeholder="Search"]')
searchfood.send_keys('Food')
time.sleep(2)
handles=driver.find_elements_by_xpath('//div[@class = "fuqBx"]//a["href"]')
time.sleep(1)
food_list=[]
for i in handles:
    if 'explore' in i.get_attribute('href'):                                    #if explore present in link then it is hastags
        continue
    else:       
        s = i.get_attribute('href').split('/')                                  #https://www.instagram.com/foodtalkindia
        print(s[3])                                     # after split s= ['https:','','www.instagram.com','foodtalkindia']
        food_list.append(s[3])
        
search=driver.find_element_by_xpath('//div[contains(@class,"aIYm8")]')
search.click()
# Out:
# __foodmachine___
# dehradun_street_food
# foofaji
# yourfoodlab
# delhifoodwalks
# foodys
# food
# food_relating_tales
# kotha.anish
# mumbaifoodie
# the_foodie_x
# food_geek1
# foodie_incarnate
# foodbible
# mealplans
# food__enthusiasts_
# food_travel_20
# foodpandit
# foodbaba_
# food_destina
# food__fantasyy
# food_streat_
# food_eggsplorer
# dilsefoodie
# food.redefined
# a.foodie.soull
# foodnetwork
# foodyworld1234
# gurgaonfoodblog
# its_luv_not_food
# foodreaction_
# food_lovers_mad
# doonfoodtales
# bhukkhadbybirth
# foodycheff
# tushar_foodie
# foodtalkindia
# foodbeast17
# science_and_food
# foody_meee
# authentic_odia_food
# a.foodie.soul
# foodyfetish
# foodgrammer_

# %% [markdown]
# ## Search for sodelhi and start following it

# %%
search=driver.find_element_by_xpath('//span[text()="Search"]')
search.click()
time.sleep(1)
searchfood= driver.find_element_by_xpath('//input[@placeholder="Search"]')
searchfood.send_keys('sodelhi')
count = 0
while count <3:
        searchfood.send_keys(Keys.ENTER)                     
        count +=1 # count = count +1
        time.sleep(1)
time.sleep(1)
follow=driver.find_element_by_xpath('//button[text()="Follow"]')
follow.click()
time.sleep(1)
print('Started Following soDelhi')
# Out:
# Started Following soDelhi

# %% [markdown]
# ## Unfollowing soDelhi

# %%
unfollow=driver.find_element_by_xpath('//span[contains(@class,"glyphsSpriteFriend_Follow u-__7")]')
unfollow.click()
time.sleep(1)
unfollow=driver.find_element_by_xpath('//button[text()="Unfollow"]')
unfollow.click()
time.sleep(1)
print('Unfollowed soDelhi')
# Out:
# Unfollowed soDelhi

# %% [markdown]
# ## Liking top 30 posts of dilsefoodie

# %%
search=driver.find_element_by_xpath('//span[text()="Search"]')
search.click()
time.sleep(1)
searchfood= driver.find_element_by_xpath('//input[@placeholder="Search"]')
searchfood.send_keys('dilsefoodie')
count = 0
while count <3:
        searchfood.send_keys(Keys.ENTER)                     
        count +=1 # count = count +1
        time.sleep(1)
time.sleep(1)
media_element = driver.find_element_by_xpath('//div[@class="eLAPa"]')
media_element.click()
time.sleep(2)
for i in range (30):
            # like
            like = driver.find_element_by_xpath('//button[@class="wpO6b "]//*[@aria-label="Like"]')
            like.click()
            time.sleep(2)
            next_button = driver.find_element_by_xpath('//a[text()="Next"]')
            next_button.click()
            time.sleep(2)

# %%
close = driver.find_element_by_xpath('//*[@aria-label="Close"]')
close.click()
driver.get('https://www.instagram.com/dilsefoodie/')

# %% [markdown]
# ## Unlike the previous 30 liked posts of dilsefoodie

# %%
media_element = driver.find_element_by_xpath('//div[@class="eLAPa"]')
media_element.click()
time.sleep(2)
for i in range (30):
            # like
            like = driver.find_element_by_xpath('//button[@class="wpO6b "]//*[@aria-label="Unlike"]')
            like.click()
            time.sleep(2)
            next_button = driver.find_element_by_xpath('//a[text()="Next"]')
            next_button.click()
            time.sleep(2)
close = driver.find_element_by_xpath('//*[@aria-label="Close"]')
close.click()

# %% [markdown]
# ## Printing first 500 followers of foodtalkindia

# %%
search=driver.find_element_by_xpath('//span[text()="Search"]')
search.click()
time.sleep(1)
searchfood= driver.find_element_by_xpath('//input[@placeholder="Search"]')
searchfood.send_keys('foodtalkindia')
count = 0
while count <3:
        searchfood.send_keys(Keys.ENTER)                     
        count +=1 # count = count +1
        time.sleep(1)
time.sleep(1)

# %%
followers=driver.find_element_by_xpath('//a[text()=" followers"]')
followers.click()
time.sleep(1)
while True:
    try:
        foodtalkindia=[]
        count=1
        while True:
            elements=driver.find_elements_by_xpath('//a[contains(@class, "notranslate")]')
            if len(elements)<500:
                waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//ul[contains(@class, "jSC57")]')))
                driver.execute_script('arguments[0].scrollIntoView(0, 100);', driver.find_element_by_xpath('//ul[contains(@class, "jSC57")]'))
                time.sleep(0.8)
            i=elements[count]
            foodtalkindia.append(i.get_attribute('innerHTML'))
            if len(foodtalkindia)>=500:
                break
            count+=1
        break
    except StaleElementReferenceException:
        continue
for i in foodtalkindia:
    print(i)
# Out:
# the_rmj
# afiq_dates
# explore.beautyof.india
# clickalmost
# 9sanakhan0
# iam_starly
# i_n_d_i_g_o_j_a_c_k_f_r_o_d_
# mayur_king_1137
# brizzles_11
# shenazjamal
# official_panghal_putt
# glocalfarms
# indiafoodtraveltales
# y_b_barad
# ganesh_dmry
# minutemeals_official
# grill_by_juss
# sunilbhaskar143
# shrutie
# axomiya.restaurant
# karthik_rv8
# crazybluluv
# riejesie
# ram_singh_8107
# swamy_rapper
# lolcentralofficial
# janav_bansal
# goutammewade5
# foodlove235
# ___yoge___
# hasslefreekhoj
# shreenidhisingh
# gurjot.kaur16
# x_house17
# everythingvere
# rupashigupta
# shanur_06
# cookingwithruji
# arohisingh_26
# haz_zle_daz_zle_abi
# the_pseudosocial
# ijaspreetgulati
# sunnygodffgamer
# am.naimul
# _____o.i.s.h.i._
# ayan_d_rz
# rinkle.bohra29
# innocent_shudhanshu_thakur_
# dineshk.kharadi.5
# sunil_prajapat_official93
# onwukauchenna588
# gaurav.arora877
# sakshidubey8643
# daino_gamer_999
# sonia_saini9
# manwith_nonam
# takeabaketoday
# rajeesh_thenissery
# ...

# %% [markdown]
# ## Printing first 500 followers of sodelhi

# %%
search=driver.find_element_by_xpath('//span[text()="Search"]')
search.click()
time.sleep(1)
searchfood= driver.find_element_by_xpath('//input[@placeholder="Search"]')
searchfood.send_keys('sodelhi')
count = 0
while count <3:
        searchfood.send_keys(Keys.ENTER)                     
        count +=1 # count = count +1
        time.sleep(1)
time.sleep(1)

# %%
followers=driver.find_element_by_xpath('//a[text()=" followers"]')
followers.click()
time.sleep(1)
while True:
    try:
        sodelhi=[]
        count=0
        while True:
            elements=driver.find_elements_by_xpath('//a[contains(@class, "notranslate")]')
            if len(elements)<500:
                waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//ul[contains(@class, "jSC57")]')))
                driver.execute_script('arguments[0].scrollIntoView(0, 100);', driver.find_element_by_xpath('//ul[contains(@class, "jSC57")]'))
                time.sleep(0.8)
            i=elements[count]
            sodelhi.append(i.get_attribute('innerHTML'))
            if len(sodelhi)>=500:
                break
            count+=1
        break
    except StaleElementReferenceException:
        continue
for i in sodelhi:
    print(i)
# Out:
# fooddogram
# manik_7881
# oficl___s_h_u_b_h_a_m
# kajalthakur__0315
# bond_8129
# maliksaab4856
# drvivekchaudhary
# medanishsid
# raaj_kapooor
# kanishq_basoya_dellhii0001
# harsh.vardhan2811
# foodz_zilla
# muddasarshaikh5571
# niishhaaaa_
# itsme.kanha_2777
# grv_dayal
# indianethnicartsandcrafts
# thegoldenmolly_
# mehulgandhii
# world_business_oppurnity
# rekhaagg836
# pine_muroo
# akash.sharma22158
# suriyavansi_ankit
# foodiekartik
# i_am_muskansingh4497
# divanshu.sharma.7
# vegf_oodie
# rohankapurphotography
# viibbbhhhhaaaaa
# aryanchaudhry_
# dng_pawankumar
# anjalirathi07
# anas_rajput_37
# shivani15singh
# paridhirwt
# karan5050kumar
# ushagargdg
# ravirj1020
# skysobeaut
# _.komal._86
# pbhajanka
# brizzles_11
# desertfestival2021
# nikhylkasana
# kuchkhayegakya
# susa_jji_ta
# nitinsharma8414_
# levlr_
# indiafoodtraveltales
# abhishekv161
# saffronindelhi
# depakbhi
# fauzan_aqueel
# shubham.sr4
# iampavan20
# perrsonaljesus
# _nonu_urs_
# janavsonu
# ...

# %% [markdown]
# ## Check story of Coding Ninjas and give error message as applicable
# ### a> No Story available
# ### b>story already Viewed
# ### c>story Not Viewed  (View it)

# %%
driver.get('https://www.instagram.com/')
time.sleep(2)
search=driver.find_element_by_xpath('//span[text()="Search"]')
search.click()
time.sleep(1)
searchfood= driver.find_element_by_xpath('//input[@placeholder="Search"]')
searchfood.send_keys('coding.ninjas')
count = 0
while count <3:
        searchfood.send_keys(Keys.ENTER)                     
        count +=1 # count = count +1
        time.sleep(1)
time.sleep(1)

# %%
story=driver.find_element_by_xpath('//div[contains(@class,"RR-M-")]')
if story.get_attribute('aria-disabled')=='true':
    print('No Story Available')
else:
    stavailable=driver.find_element_by_xpath('//canvas[@class="CfWVH"]')
    if int(stavailable.get_attribute('height'))<91 and int(stavailable.get_attribute('width'))<91:
        print('Story Already Seen')
    else:
        print('Story Not seen')
        if input('press 1 to See : '):
            story.click()
            print('Story viewed')
# Out:
# Story Not seen
# press 1 to See : 1
# Story viewed
